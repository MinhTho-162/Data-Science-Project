# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://rever.vn/mua/can-ho-dao-kim-cuong-tang-trung-don-view-thanh-pho-sam-uat'
html_text = requests.get(url).text

# %%
tree = BeautifulSoup(html_text, 'html.parser')
tree
# Out:
# <!DOCTYPE html>
#
# <html lang="vi" xmlns="http://www.w3.org/1999/xhtml" xmlns:addthis="http://www.addthis.com/help/api-spec">
# <head>
# <script>
#   /*@shinsenter/defer.js*/
# ...

# %%
#houses = tree.find_all('div', {'class': 'content'})
houses_left = tree.find_all('p', {'class': 'left'})
len(houses_left)
# Out:
# 65

# %%
houses_left
# Out:
# [<p class="left">Loại hình</p>,
#  <p class="left">Phòng ngủ</p>,
#  <p class="left">Phòng tắm</p>,
#  <p class="left">Diện tích</p>,
#  <p class="left">Diện tích sử dụng</p>,
#  <p class="left">Tình hình nội thất</p>,
#  <p class="left">Loại chủ quyền</p>,
#  <p class="left">Dự án</p>,
#  <p class="left">Tháp</p>,
#  <p class="left">Trạng thái</p>,
#  <p class="left">Giá bán</p>,
#  <p class="left">Ban công</p>,
#  <p class="left">Phòng cho giúp việc</p>,
#  <p class="left">Sân vườn</p>,
#  <p class="left">Phòng giải trí</p>,
#  <p class="left">Chỗ đậu xe hơi</p>,
#  <p class="left">Hồ bơi riêng</p>,
#  <p class="left">Quầy minibar</p>,
#  <p class="left">Tầng hầm</p>,
#  <p class="left">Góc làm việc</p>,
#  <p class="left">Nhà kho</p>,
#  <p class="left">Nuôi thú cưng</p>,
#  <p class="left">Gym</p>,
#  <p class="left">Bàn ghế phòng khách</p>,
#  <p class="left">Kệ TV</p>,
#  <p class="left">Bộ bàn ăn và ghế</p>,
#  <p class="left">Đảo bếp
#  </p>,
# ...

# %%
houses_right = tree.find_all('p', {'class': 'right'})
#len(houses_right)
#houses_right.find('p', {'class': 'right'})

#for house_right in houses_right:
    
    #left = house.find('a', {'class': 'left'}).string
   
    #left = house.find('a', {'class': 'left'})
    #print(left)
    
    #right = house_right.find('p', {'class': 'right'})
    #right = house.find('p', {'class': 'right'})
    #print(right).slit()
    #type(left)

# %%
houses_right
# Out:
# [<p class="right"><a href="/s/ho-chi-minh/mua/can-ho" target="_blank">Căn hộ</a></p>,
#  <p class="right"><a href="/s/ho-chi-minh/mua/2-phong-ngu" target="_blank">2</a></p>,
#  <p class="right">2</p>,
#  <p class="right">83.31 m²</p>,
#  <p class="right">83.31 m²</p>,
#  <p class="right">Đầy đủ nội thất</p>,
#  <p class="right">HĐ mua bán</p>,
#  <p class="right"><a href="/s/dao-kim-cuong-diamond-island/mua" target="_blank">Đảo Kim Cương - Diamond Island</a></p>,
#  <p class="right">Canary</p>,
#  <p class="right">Chưa bàn giao</p>,
#  <p class="right">5.05 tỷ</p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
#  <p class="right zmdi zmdi-close"></p>,
# ...

# %%
s = tree.find_all('ul', {'class': 'detail-more'}) 
s 
len(s)
print(s)
# Out:
# [<ul class="detail-more">
# <li>
# <p class="left">Loại hình</p>
# <p class="right"><a href="/s/ho-chi-minh/mua/can-ho" target="_blank">Căn hộ</a></p>
# </li>
# <li>
# <p class="left">Phòng ngủ</p>
# <p class="right"><a href="/s/ho-chi-minh/mua/2-phong-ngu" target="_blank">2</a></p>
# </li>
# <li>
# <p class="left">Phòng tắm</p>
# <p class="right">2</p>
# </li>
# <li>
# <p class="left">Diện tích</p>
# <p class="right">83.31 m²</p>
# </li>
# <li>
# <p class="left">Diện tích sử dụng</p>
# <p class="right">83.31 m²</p>
# </li>
# <li>
# <p class="left">Tình hình nội thất</p>
# <p class="right">Đầy đủ nội thất</p>
# </li>
# <li>
# <p class="left">Loại chủ quyền</p>
# <p class="right">HĐ mua bán</p>
# </li>
# <li>
# <p class="left">Dự án</p>
# <p class="right"><a href="/s/dao-kim-cuong-diamond-island/mua" target="_blank">Đảo Kim Cương - Diamond Island</a></p>
# </li>
# <li>
# <p class="left">Tháp</p>
# <p class="right">Canary</p>
# </li>
# <li>
# <p class="left">Trạng thái</p>
# ...

# %%
for house_right in houses_right:
    print(house_right.text)
# Out:
# Căn hộ
# 2
# 2
# 83.31 m²
# 83.31 m²
# Đầy đủ nội thất
# HĐ mua bán
# Đảo Kim Cương - Diamond Island
# Canary
# Chưa bàn giao
# 5.05 tỷ

# %%
for house_left in houses_left:
    print(house_left.text.strip())
# Out:
# Loại hình
# Phòng ngủ
# Phòng tắm
# Diện tích
# Diện tích sử dụng
# Tình hình nội thất
# Loại chủ quyền
# Dự án
# Tháp
# Trạng thái
# Giá bán
# Ban công
# Phòng cho giúp việc
# Sân vườn
# Phòng giải trí
# Chỗ đậu xe hơi
# Hồ bơi riêng
# Quầy minibar
# Tầng hầm
# Góc làm việc
# Nhà kho
# Nuôi thú cưng
# Gym
# Bàn ghế phòng khách
# Kệ TV
# Bộ bàn ăn và ghế
# Đảo bếp
# Đèn trang trí
# Bếp ướt
# Bếp khô
# Tủ bếp trên
# Tủ bếp dưới
# Sàn gỗ
# Tủ âm tường
# Tủ treo đồ / tủ quần áo
# Tủ kê đầu giường
# Đèn trần
# Đèn bàn
# Giường
# Đệm, chăn, gối
# Tủ giày dép
# Bồn tắm
# Kệ sách
# Bàn làm việc
# Bàn trang điểm
# TV
# Máy hút mùi
# Cảm biến cháy
# Tủ lạnh
# Bếp ga, bếp từ
# Máy giặt
# Máy sấy
# Dàn phơi đồ thông minh
# Máy lạnh
# Máy nước nóng
# Khóa cửa thẻ từ
# Khóa cửa mật khẩu
# Khóa cửa vân tay
# Thiết bị âm thanh
# Smart Home
# Lò nướng
# Lò vi sóng
# Camera an ninh
# Internet
# Truyền hình cáp
